# %% [markdown]
# # Project Description

# %% [markdown]
# For this project data from [Open Street map](https://www.openstreetmap.org/#map=5/51.500/-0.100) is downloaded. The data comes in the xml format and gets wrangeled and than stored in a mongo db database.
#
# Therfore, the data is inspected for inconsistend or false values, in the next step the data is cleaned and than transformed for storing in a MongoDB database.

# %% [markdown]
# # Import Libaries

# %%
import os
from sys import exit
import urllib.request

from collections import defaultdict
import re
import pprint

import xml.etree.cElementTree as ElementTree

from pymongo import MongoClient
from bson.objectid import ObjectId

# %% [markdown]
# # Set Global Variables

# %%
URL = 'http://overpass-api.de/api/map?bbox=11.4388,48.0593,11.6448,48.2507'
DATASET_NAME = 'muenchen'
DATASET_PATH = 'data/' + DATASET_NAME + '.osm'
SAMPLE_PATH = 'data/' + DATASET_NAME + '_sample' + '.osm'

MONGODB_DB = 'mongodb://localhost:27017'

# %% [markdown]
# # Project Preparation

# %% [markdown]
# ## Function download the map data

# %%
def load_OpenStreetMap_data(url, path):
    """Download a xml file representing an area based on the openstreetmap data

    Args:
        url of xml map
        path file name to for storage

    Returns:
        None
    """
    ### Create data dir if not exts
    if not os.path.exists('data/'):
        os.makedirs('data/')
    
    urllib.request.urlretrieve(url, path)

# %% [markdown]
# ## Function sample generation for auditing

# %%
def sample_xml_data(path, path_sample, k):
    """Creates a sample of a given openstreetmap file and stores the sample to disc

    Args:
        path of the original osm file
        path of the sample osm file
        k nth element that should be sampled

    Returns:
        None
    """
    
    def get_element(osm_file, tags=('node', 'way', 'relation')):
        """Yield element if it is the right type of tag

        Reference:
        http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
        """
        context = iter(ElementTree.iterparse(osm_file, events=('start', 'end')))
        _, root = next(context)
        for event, elem in context:
            if event == 'end' and elem.tag in tags:
                yield elem
                root.clear()


    with open(path_sample, 'w') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\r\n')
        output.write('<osm>\r\n  ')

        # Write every kth top level element
        for i, element in enumerate(get_element(path)):
            if i % k == 0:
                #output.write(str(ElementTree.tostring(element, encoding='utf-8')))
                output.write(str(ElementTree.tostring(element))+'\r\n')
        output.write('</osm>')

# %% [markdown]
# # Load the Dataset

# %%
"""
Downloads the data to the data folder of a local repository after you run it once you can uncomment this lines.
To prevent the code from downloading the data every time you run the code.
"""  
#load_OpenStreetMap_data(URL, DATASET_PATH)

"""
Generate s a sample of the dataset for the auditing process after you run it once you can uncomment this lines.
To prevent the code from downloading the data every time you run the code.
"""  
#sample_xml_data(DATASET_PATH, SAMPLE_PATH, 100)
# Out:
# '\nGenerate s a sample of the dataset for the auditing process after you run it once you can uncomment this lines.\nTo prevent the code from downloading the data every time you run the code.\n'

# %% [markdown]
# # Audit of the data

# %% [markdown]
# ## Audit functions

# %% [markdown]
# ### Generic function

# %%
def audit_tag(tag_type, expected=[], splitting=False):
    """Audits a given tag type in the xml file

    Args:
        tag_type tag in the xml file that should be audited
        expected values that are marked as correct
        splitting specifies if the value should be split based on punctation

    Returns:
        None
    """
    
    ### Checks if tag is equal the tag specified 
    def is_tag_type(element, tag_type):
        return (element.attrib['k'] == tag_type)

    ### Audtis the tag value
    def audit_tag_type(tag_types, tag_type, expected, splitting):
    
        if splitting:
            tag_type = tag_type.split(',')[0]
            tag_type = tag_type.split(';')[0]
            tag_type = tag_type.split('_')[0]
            tag_type = tag_type.lower()

        if tag_type not in expected:
                tag_types[tag_type].add(tag_type)
    
    ### Load xml file
    osm_file = open(SAMPLE_PATH, "rb")
    
    ### Creates the dict for storing the invalid values
    tag_types = defaultdict(set)
    
    ### Loops over the xml file and audit the tag
    for event, element in ElementTree.iterparse(osm_file, events=("start",)):
        if element.tag == "node" or element.tag == "way":
            for tag in element.iter('tag'):
                if is_tag_type(tag, tag_type):
                    #tag_types[tag.attrib['v']].add(tag.attrib['v'])
                    audit_tag_type(tag_types, tag.attrib['v'], expected, splitting)
                
    ### Close the connection to the file
    osm_file.close()
    
    ### Prints the values that not marked as valid
    pprint.pprint(tag_types)

# %% [markdown]
# ### Generic regex function

# %%
def audit_tag_reg(tag_type, regex = ".*"):
    """Audits a given tag type in the xml file

    Args:
        tag_type tag in the xml file that should be audited
        regex specifies a regex that describes valid values
        
    Returns:
        None
    """
    
    ### Checks if tag is equal the tag specified 
    def is_tag_type_reg(element, tag_type):
        return (element.attrib['k'] == tag_type)

    ### Audtis the tag value
    def audit_tag_type_reg(tag_types, tag_type, regex):
    
        audit_tag_type_re = re.compile(regex, re.IGNORECASE)

        m = audit_tag_type_re.search(tag_type)

        if m:
            tag_type_name = m.group()

            tag_types[tag_type_name].add(tag_type)

    ### Load xml file
    osm_file = open(SAMPLE_PATH, "rb")
    
    ### Creates the dict for storing the invalid values
    tag_types = defaultdict(set)
    
    ### Loops over the xml file and audit the tag
    for event, element in ElementTree.iterparse(osm_file, events=("start",)):
        if element.tag == "node" or element.tag == "way":
            for tag in element.iter('tag'):
                if is_tag_type_reg(tag, tag_type):
                    #tag_types[tag.attrib['v']].add(tag.attrib['v'])
                    audit_tag_type_reg(tag_types, tag.attrib['v'], regex)
    
    ### Close the connection to the file
    osm_file.close()
    
    ### Prints the values that not marked as valid
    pprint.pprint(tag_types)

# %% [markdown]
# ### Specific street function

# %%
def audti_street_names(expected=[]):
    """Audits a given street name

    Args:
        expected values that are marked as correct
        
    Returns:
        None
    """
    
    ### Checks if tag is equal the tag specified 
    def is_street_name(element):
        return (element.attrib['k'] == "addr:street")

    ### Audtis the tag value
    def audit_street_type(street_types, street_name, expected):

        street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)

        m = street_type_re.search(street_name)

        if m:
            street_type = m.group()
            if street_type not in expected:
                street_types[street_type].add(street_name)
            #street_types[street_type] += 1
    
    ### Load xml file
    osm_file = open(SAMPLE_PATH, "rb")
    
    ### Creates the dict for storing the invalid values
    street_types = defaultdict(set)
    
    ### Loops over the xml file and audit the tag
    for event, element in ElementTree.iterparse(osm_file, events=("start",)):
        if element.tag == "node" or element.tag == "way":
            for tag in element.iter('tag'):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'], expected)
    
    ### Close the connection to the file
    osm_file.close()
    
    ### Prints the values that not marked as valid
    pprint.pprint(street_types)

# %% [markdown]
# ## Audit housenumbers

# %%
### Audit the housenumber tag of the xml file
audit_tag("addr:housenumber")
# Out:
# defaultdict(<class 'set'>,
#             {'1': {'1'},
#              '10': {'10'},
#              '10-18': {'10-18'},
#              '100': {'100'},
#              '101': {'101'},
#              '102': {'102'},
#              '102b': {'102b'},
#              '103': {'103'},
#              '104': {'104'},
#              '105': {'105'},
#              '106': {'106'},
#              '107': {'107'},
#              '107a': {'107a'},
#              '109': {'109'},
#              '10a': {'10a'},
#              '10c': {'10c'},
#              '10e': {'10e'},
#              '11': {'11'},
#              '110': {'110'},
#              '111': {'111'},
#              '111a': {'111a'},
#              '112': {'112'},
#              '113': {'113'},
#              '114': {'114'},
#              '114a': {'114a'},
#              '115': {'115'},
#              '116': {'116'},
#              '117': {'117'},
#              '117c': {'117c'},
#              '118': {'118'},
#              '118b': {'118b'},
#              '119': {'119'},
#              '11a': {'11a'},
#              '12': {'12'},
#              '120': {'120'},
#              '121': {'121'},
#              '124': {'124'},
#              '126': {'126'},
#              '129': {'129'},
#              '12a': {'12a'},
#              '12b': {'12b'},
#              '12d': {'12d'},
#              '12e': {'12e'},
#              '13': {'13'},
#              '130': {'130'},
#              '131': {'131'},
#              '132a': {'132a'},
#              '136': {'136'},
#              '137': {'137'},
#              '138': {'138'},
#              '13a': {'13a'},
#              '14': {'14'},
#              '140': {'140'},
#              '142': {'142'},
#              '143': {'143'},
#              '145a': {'145a'},
#              '146': {'146'},
#              '148b': {'148b'},
#              '14a': {'14a'},
#              '14i': {'14i'},
#              '15': {'15'},
#              '150a': {'150a'},
#              '151': {'151'},
#              '154': {'154'},
#              '156': {'156'},
#              '157': {'157'},
#              '158': {'158'},
#              '15a': {'15a'},
#              '15b': {'15b'},
#              '16': {'16'},
#              '160': {'160'},
#              '162': {'162'},
#              '165': {'165'},
#              '167': {'167'},
#              '168b': {'168b'},
#              '16a': {'16a'},
#              '16b': {'16b'},
#              '16c': {'16c'},
#              '17': {'17'},
#              '17-19': {'17-19'},
#              '170': {'170'},
#              '171': {'171'},
#              '175': {'175'},
#              '176f': {'176f'},
#              '17a': {'17a'},
#              '17d': {'17d'},
#              '18': {'18'},
#              '181': {'181'},
#              '183': {'183'},
#              '185': {'185'},
#              '189': {'189'},
#              '18a': {'18a'},
#              '18b': {'18b'},
#              '19': {'19'},
#              '195': {'195'},
#              '197': {'197'},
#              '19b': {'19b'},
#              '19c': {'19c'},
#              '19g': {'19g'},
#              '1;1a': {'1;1a'},
#              '1a': {'1a'},
#              '1d': {'1d'},
#              '2': {'2'},
#              '20': {'20'},
#              '201': {'201'},
#              '201b': {'201b'},
#              '204': {'204'},
#              '204a': {'204a'},
#              '209e': {'209e'},
#              '20a': {'20a'},
#              '20b': {'20b'},
#              '20c': {'20c'},
#              '21': {'21'},
#              '212': {'212'},
#              '219': {'219'},
#              '21a': {'21a'},
#              '21b': {'21b'},
#              '21c': {'21c'},
#              '22': {'22'},
#              '224': {'224'},
#              '225': {'225'},
#              '22a': {'22a'},
#              '23': {'23'},
#              '236': {'236'},
#              '238': {'238'},
#              '23a': {'23a'},
#              '76a': {'76a'},
#              '77': {'77'},
#              '77a': {'77a'},
#              '78': {'78'},
#              '79': {'79'},
#              '7a': {'7a'},
#              '7b': {'7b'},
#              '7c': {'7c'},
#              '8': {'8'},
#              '80': {'80'},
#              '80e': {'80e'},
#              '81a': {'81a'},
#              '82': {'82'},
#              '82a': {'82a'},
#              '83': {'83'},
#              '83a': {'83a'},
#              '85': {'85'},
#              '85a': {'85a'},
#              '86a': {'86a'},
#              '87': {'87'},
#              '88': {'88'},
#              '89a': {'89a'},
#              '89b': {'89b'},
#              '8a': {'8a'},
#              '8c': {'8c'},
#              '9': {'9'},
#              '92': {'92'},
#              '92a': {'92a'},
#              '93': {'93'},
#              '94': {'94'},
#              '95': {'95'},
#              '96': {'96'},
#              '97': {'97'},
#              '98': {'98'},
#              '99c': {'99c'},
#              '9a': {'9a'},
#              '9b': {'9b'},
#              '9c': {'9c'}})

# %% [markdown]
# ## Audit postcodes

# %%
### Audit the postcode tag of the xml file any code consiting of 5 numbers is expected to be valid
#audit_tag("addr:postcode")
audit_tag_reg("addr:postcode", "^(?![0-9]{5})")
# Out:
# defaultdict(<class 'set'>, {})

# %% [markdown]
# ## Audit street

# %%
### Audit the street names tag of the xml file
audti_street_names()
# Out:
# defaultdict(<class 'set'>,
#             {'Abensbergstraße': {'Abensbergstraße'},
#              'Abenthumstraße': {'Abenthumstraße'},
#              'Aberlestraße': {'Aberlestraße'},
#              'Achatstraße': {'Achatstraße'},
#              'Adalbertstraße': {'Adalbertstraße'},
#              'Adam-Berg-Straße': {'Adam-Berg-Straße'},
#              'Adelsbergstraße': {'Adelsbergstraße'},
#              'Adenauerring': {'Adenauerring'},
#              'Adolf-Mathes-Weg': {'Adolf-Mathes-Weg'},
#              'Aggensteinstraße': {'Aggensteinstraße'},
#              'Agilolfingerplatz': {'Agilolfingerplatz'},
#              'Agnes-Bernauer-Straße': {'Agnes-Bernauer-Straße'},
#              'Agnes-Miegel-Straße': {'Agnes-Miegel-Straße'},
#              'Agricolastraße': {'Agricolastraße'},
#              'Aiblingerstraße': {'Aiblingerstraße'},
#              'Aidenbachstraße': {'Aidenbachstraße'},
#              'Aindorferstraße': {'Aindorferstraße'},
#              'Albert-Roßhaupter-Straße': {'Albert-Roßhaupter-Straße'},
#              'Albert-Schweitzer-Straße': {'Albert-Schweitzer-Straße'},
#              'Alfred-Kubin-Weg': {'Alfred-Kubin-Weg'},
#              'Alfred-Pongratz-Weg': {'Alfred-Pongratz-Weg'},
#              'Allee': {'Forstenrieder Allee', 'Landshuter Allee', 'Alte Allee'},
#              'Allescherstraße': {'Allescherstraße'},
#              'Alois-Gilg-Weg': {'Alois-Gilg-Weg'},
#              'Alpenstraße': {'Alpenstraße'},
#              'Alpspitzring': {'Alpspitzring'},
#              'Altdorferstraße': {'Altdorferstraße'},
#              'Amalienstraße': {'Amalienstraße'},
#              'Ammerseestraße': {'Ammerseestraße'},
#              'Ampfingstraße': {'Ampfingstraße'},
#              'Andreas-Sengl-Weg': {'Andreas-Sengl-Weg'},
#              'Flotowstraße': {'Flotowstraße'},
#              'Floßmannstraße': {'Floßmannstraße'},
#              'Forst-Kasten-Allee': {'Forst-Kasten-Allee'},
#              'Forstweg': {'Perlacher Forstweg'},
#              'Fraasstraße': {'Fraasstraße'},
#              'Franz-Hauser-Weg': {'Franz-Hauser-Weg'},
#              'Franz-Josef-Strauß-Ring': {'Franz-Josef-Strauß-Ring'},
#              'Franz-Kötterl-Straße': {'Franz-Kötterl-Straße'},
#              'Franz-Nißl-Straße': {'Franz-Nißl-Straße'},
#              'Franz-Senn-Straße': {'Franz-Senn-Straße'},
#              'Franz-Sperr-Weg': {'Franz-Sperr-Weg'},
#              'Franz-Werfel-Straße': {'Franz-Werfel-Straße'},
#              'Frauenchiemseestraße': {'Frauenchiemseestraße'},
#              'Frauenmantelanger': {'Frauenmantelanger'},
#              'Frauenplatz': {'Frauenplatz'},
#              'Frauenstraße': {'Frauenstraße'},
#              'Freibadstraße': {'Freibadstraße'},
#              'Freischützstraße': {'Freischützstraße'},
#              'Freseniusstraße': {'Freseniusstraße'},
#              'Freystraße': {'Freystraße'},
#              'Friedenstraße': {'Friedenstraße'},
#              'Friedrich-Eckart-Straße': {'Friedrich-Eckart-Straße'},
#              'Friedrich-Herschel-Straße': {'Friedrich-Herschel-Straße'},
#              'Friedrich-König-Weg': {'Friedrich-König-Weg'},
#              'Friedrich-Zahn-Straße': {'Friedrich-Zahn-Straße'},
#              'Friedrichstraße': {'Friedrichstraße'},
#              'Fritz-Baer-Straße': {'Fritz-Baer-Straße'},
#              'Fritz-Berne-Straße': {'Fritz-Berne-Straße'},
#              'Fritz-Lange-Straße': {'Fritz-Lange-Straße'},
#              'Fritz-Meyer-Weg': {'Fritz-Meyer-Weg'},
#              'Fritz-Reuter-Straße': {'Fritz-Reuter-Straße'},
#              'Fromundstraße': {'Fromundstraße'},
#              'Frundsbergstraße': {'Frundsbergstraße'},
#              'Fuetererstraße': {'Fuetererstraße'},
#              'Führichstraße': {'Führichstraße'},
#              'Fürstenackerstraße': {'Fürstenackerstraße'},
#              'Fürstenbergstraße': {'Fürstenbergstraße'},
#              'Gabriel-von-Seidl-Straße': {'Gabriel-von-Seidl-Straße'},
#              'Gaggenaystraße': {'Gaggenaystraße'},
#              'Gailkircherstraße': {'Gailkircherstraße'},
#              'Gaisbergstraße': {'Gaisbergstraße'},
#              'Gaishoferstraße': {'Gaishoferstraße'},
#              'Ganghoferstraße': {'Ganghoferstraße'},
#              'Gartenstraße': {'Gartenstraße'},
#              'Gaßnerstraße': {'Gaßnerstraße'},
#              'Gebsattelstraße': {'Gebsattelstraße'},
#              'Geiselgasteigstraße': {'Geiselgasteigstraße'},
#              'Georg-Brauchle-Ring': {'Georg-Brauchle-Ring'},
#              'Georg-Habel-Straße': {'Georg-Habel-Straße'},
#              'Georg-Hann-Straße': {'Georg-Hann-Straße'},
#              'Georg-Reismüller-Straße': {'Georg-Reismüller-Straße'},
#              'Georg-Wopfner-Straße': {'Georg-Wopfner-Straße'},
#              'Germaniastraße': {'Germaniastraße'},
#              'Pestalozzistraße': {'Pestalozzistraße'},
#              'Peter-Kreuder-Straße': {'Peter-Kreuder-Straße'},
#              'Peter-Winter-Straße': {'Peter-Winter-Straße'},
#              'Petersenstraße': {'Petersenstraße'},
#              'Petersplatz': {'Petersplatz'},
#              'Petra-Kelly-Straße': {'Petra-Kelly-Straße'},
#              'Petzetstraße': {'Petzetstraße'},
#              'Pfanzeltplatz': {'Pfanzeltplatz'},
#              'Pfarrer-Grimm-Straße': {'Pfarrer-Grimm-Straße'},
#              'Pfarrstraße': {'Pfarrstraße'},
#              'Pfeuferstraße': {'Pfeuferstraße'},
#              'Pflegerstraße': {'Pflegerstraße'},
#              'Pfänderstraße': {'Pfänderstraße'},
#              'Philipp-Reis-Straße': {'Philipp-Reis-Straße'},
#              'Pienzenauerstraße': {'Pienzenauerstraße'},
#              'Pinienweg': {'Pinienweg'},
#              'Pirmaterstraße': {'Pirmaterstraße'},
#              'Pittingerstraße': {'Pittingerstraße'},
#              'Platz': {'Genfer Platz',
#                        'Glogauer Platz',
#                        'Milbertshofener Platz',
#                        'Tiroler Platz',
#                        'Weißenburger Platz'},
#              'Plinganserstraße': {'Plinganserstraße'},
#              'Polkostraße': {'Polkostraße'},
#              'Pommernstraße': {'Pommernstraße'},
#              'Portenstraße': {'Portenstraße'},
#              'Prangerlstraße': {'Prangerlstraße'},
#              'Praschlerstraße': {'Praschlerstraße'},
#              'Preußenstraße': {'Preußenstraße'},
#              'Preziosastraße': {'Preziosastraße'},
#              'Prießnitzstraße': {'Prießnitzstraße'},
#              'Prinzregentenplatz': {'Prinzregentenplatz'},
#              'Prinzregentenstraße': {'Prinzregentenstraße'},
#              'Prochintalstraße': {'Prochintalstraße'},
#              'Prälat-Wellenhofer-Straße': {'Prälat-Wellenhofer-Straße'},
#              'Puechbergerstraße': {'Puechbergerstraße'},
#              'Pulverturmstraße': {'Pulverturmstraße'},
#              'Pählstraße': {'Pählstraße'},
#              'Pössenbacherstraße': {'Pössenbacherstraße'},
#              'Pötschnerstraße': {'Pötschnerstraße'},
#              'Quagliostraße': {'Quagliostraße'},
#              'Quiddestraße': {'Quiddestraße'},
#              'Rablstraße': {'Rablstraße'},
#              'Radeckestraße': {'Radeckestraße'},
#              'Radenhölzl': {'Am Radenhölzl'},
#              'Rainackerweg': {'Rainackerweg'},
#              'Ramoltstraße': {'Ramoltstraße'},
#              'Rathenaustraße': {'Rathenaustraße'},
#              'Rathochstraße': {'Rathochstraße'},
#              'Rechpacherstraße': {'Rechpacherstraße'},
#              'Redlingerplatz': {'Redlingerplatz'},
#              'Reginbaldstraße': {'Reginbaldstraße'},
#              'Rehbergstraße': {'Rehbergstraße'},
#              'Reichenbachstraße': {'Reichenbachstraße'},
#              'Reigersbachstraße': {'Reigersbachstraße'},
#              'Reinachstraße': {'Reinachstraße'},
#              'Reindlstraße': {'Reindlstraße'},
#              'Reischlweg': {'Reischlweg'},
#              'Reitknechtstraße': {'Reitknechtstraße'},
#              'Reschenbachstraße': {'Reschenbachstraße'},
#              'Reschreiterstraße': {'Reschreiterstraße'},
#              'Sedlmayrstraße': {'Sedlmayrstraße'},
#              'Seebergerstraße': {'Seebergerstraße'},
#              'Seeligerstraße': {'Seeligerstraße'},
#              'Seilerweg': {'Seilerweg'},
#              'Sendlinger-Tor-Platz': {'Sendlinger-Tor-Platz'},
#              'Senftlstraße': {'Senftlstraße'},
#              'Sentilostraße': {'Sentilostraße'},
#              'Sertürnerstraße': {'Sertürnerstraße'},
#              'Seuffertstraße': {'Seuffertstraße'},
#              'Sickenbergerstraße': {'Sickenbergerstraße'},
#              'Siegesstraße': {'Siegesstraße'},
#              'Siegmund-Schacky-Straße': {'Siegmund-Schacky-Straße'},
#              'Silberdistelstraße': {'Silberdistelstraße'},
#              'Simrockstraße': {'Simrockstraße'},
#              'Simsseestraße': {'Simsseestraße'},
#              'Sintpertstraße': {'Sintpertstraße'},
#              'Situlistraße': {'Situlistraße'},
#              'Skabiosenplatz': {'Skabiosenplatz'},
#              'Sommerstraße': {'Sommerstraße'},
#              'Sonnenstraße': {'Sonnenstraße'},
#              'Sonnentaustraße': {'Sonnentaustraße'},
#              'Sonnenweg': {'Sonnenweg'},
#              'Sophienstraße': {'Sophienstraße'},
#              'Soyerhofstraße': {'Soyerhofstraße'},
#              'Specklstraße': {'Specklstraße'},
#              'Spiegelbergstraße': {'Spiegelbergstraße'},
#              'Spindlerstraße': {'Spindlerstraße'},
#              'Spitzelbergstraße': {'Spitzelbergstraße'},
#              'Spitzerstraße': {'Spitzerstraße'},
#              'Spixstraße': {'Spixstraße'},
#              'Spreestraße': {'Spreestraße'},
#              'Stademannstraße': {'Stademannstraße'},
#              'Stadlerweg': {'Stadlerweg'},
#              'Staudengarten': {'Am Staudengarten'},
#              'Staudingerstraße': {'Staudingerstraße'},
#              'Steinbergerstraße': {'Steinbergerstraße'},
#              'Steinerweg': {'Steinerweg'},
#              'Steinstraße': {'Steinstraße'},
#              'Stolzingstraße': {'Stolzingstraße'},
#              'Straße': {'Aichacher Straße',
#                         'Allacher Straße',
#                         'Allmannshausener Straße',
#                         'Amberger Straße',
#                         'Appenzeller Straße',
#                         'Arader Straße',
#                         'Ascholdinger Straße',
#                         'Baierbrunner Straße',
#                         'Barer Straße',
#                         'Berenter Straße',
#                         'Berliner Straße',
#                         'Berner Straße',
#                         'Bernrieder Straße',
#                         'Biedersteiner Straße',
#                         'Blumenauer Straße',
#                         'Bonner Straße',
#                         'Boschetsrieder Straße',
#                         'Breisacher Straße',
#                         'Breitbrunner Straße',
#                         'Breslauer Straße',
#                         'Brettener Straße',
#                         'Brienner Straße',
#                         'Buchendorfer Straße',
#                         'Budapester Straße',
#                         'Böcksteiner Straße',
#                         'Dachauer Straße',
#                         'Denninger Straße',
#                         'Dietersheimer Straße',
#                         'Donaustaufer Straße',
#                         'Donauwörther Straße',
#                         'Dresdner Straße',
#                         'Düsseldorfer Straße',
#                         'Echardinger Straße',
#                         'Eggmühler Straße',
#                         'Ehrenbreitsteiner Straße',
#                         'Ehrwalder Straße',
#                         'Eininger Straße',
#                         'Elmauer Straße',
#                         'Elsässer Straße',
#                         'Englschalkinger Straße',
#                         'Eslarner Straße',
#                         'Feldmochinger Straße',
#                         'Fischbachauer Straße',
#                         'Flossenbürger Straße',
#                         'Frasdorfer Straße',
#                         'Friedenheimer Straße',
#                         'Fürstenrieder Straße',
#                         'Füssener Straße',
#                         'Geisenbrunner Straße',
#                         'Gondershauser Straße',
#                         'Grafinger Straße',
#                         'Gräfelfinger Straße',
#                         'Grünwalder Straße',
#                         'Gufidauner Straße',
#                         'Görlitzer Straße',
#                         'Görzer Straße',
#                         'Habacher Straße',
#                         'Hanauer Straße',
#                         'Hechendorfer Straße',
#                         'Heidenheimer Straße',
#                         'Heiterwanger Straße',
#                         'Hohenlindener Straße',
#                         'Höglwörther Straße',
#                         'Immenstadter Straße',
#                         'Innere Wiener Straße',
#                         'Insterburger Straße',
#                         'Ismaninger Straße',
#                         'Johanneskirchner Straße',
#                         'Karlsfelder Straße',
#                         'Klagenfurter Straße',
#                         'Kleinhaderner Straße',
#                         'Konitzer Straße',
#                         'Konstanzer Straße',
#                         'Kremser Straße',
#                         'Kronacher Straße',
#                         'Kulmer Straße',
#                         'Laimer Straße',
#                         'Landsberger Straße',
#                         'Langbürgener Straße',
#                         'Lauinger Straße',
#                         'Leipziger Straße',
#                         'Lerchenauer Straße',
#                         'Leuthener Straße',
#                         'Leutstettener Straße',
#                         'Liegnitzer Straße',
#                         'Lochhamer Straße',
#                         'Lothringer Straße',
#                         'Mainzer Straße',
#                         'Mallersdorfer Straße',
#                         'Mannheimer Straße',
#                         'Marienburger Straße',
#                         'Mattighofer Straße',
#                         'Menzinger Straße',
#                         'Miesbacher Straße',
#                         'Milbertshofener Straße',
#                         'Murnauer Straße',
#                         'Mühlthaler Straße',
#                         'Münchberger Straße',
#                         'Münchner Straße',
#                         'Naumburger Straße',
#                         'Nederlinger Straße',
#                         'Neubiberger Straße',
#                         'Neufriedenheimer Straße',
#                         'Neuhauser Straße',
#                         'Neumarkter Straße',
#                         'Neurieder Straße',
#                         'Nymphenburger Straße',
#                         'Nürnberger Straße',
#                         'Oberbiberger Straße',
#                         'Oberföhringer Straße',
#                         'Obernzeller Straße',
#                         'Oberviechtacher Straße',
#                         'Oberölkofener Straße',
#                         'Ofener Straße',
#                         'Ohlauer Straße',
#                         'Oppenrieder Straße',
#                         'Osnabrücker Straße',
#                         'Ottobrunner Straße',
#                         'Partenkirchner Straße',
#                         'Pasinger Straße',
#                         'Peretshofener Straße',
#                         'Perlacher Straße',
#                         'Pilgersheimer Straße',
#                         'Planegger Straße',
#                         'Plattlinger Straße',
#                         'Possenhofener Straße',
#                         'Preßburger Straße',
#                         'Pöckinger Straße',
#                         'Radstädter Straße',
#                         'Raidinger Straße',
#                         'Ramersdorfer Straße',
#                         'Rappoltsteiner Straße',
#                         'Rattenberger Straße',
#                         'Riedener Straße',
#                         'Rosenheimer Straße',
#                         'Rottacher Straße',
#                         'Rößeler Straße',
#                         'Saarlouiser Straße',
#                         'Schleißheimer Straße',
#                         'Schwarzenbacher Straße',
#                         'Schweidnitzer Straße',
#                         'Sendlinger Straße',
#                         'Sollner Straße',
#                         'Solothurner Straße',
#                         'Stadelheimer Straße',
#                         'Starnberger Straße',
#                         'Stockdorfer Straße',
#                         'Säbener Straße',
#                         'Terlaner Straße',
#                         'Tessiner Straße',
#                         'Thalkirchner Straße',
#                         'Tittmoninger Straße',
#                         'Traminer Straße',
#                         'Traunreuter Straße',
#                         'Triester Straße',
#                         'Trostberger Straße',
#                         'Truderinger Straße',
#                         'Uffinger Straße',
#                         'Ungsteiner Straße',
#                         'Unterbiberger Straße',
#                         'Unterhachinger Straße',
#                         'Untermenzinger Straße',
#                         'Uttinger Straße',
#                         'Veldener Straße',
#                         'Villacher Straße',
#                         'Wackersberger Straße',
#                         'Walliser Straße',
#                         'Warngauer Straße',
#                         'Wemdinger Straße',
#                         'Wessobrunner Straße',
#                         'Westerhamer Straße',
#                         'Weyarner Straße',
#                         'Wittenberger Straße',
#                         'Wolfratshauser Straße',
#                         'Zamdorfer Straße'},
#              'Stroblstraße': {'Stroblstraße'},
#              'Stäblistraße': {'Stäblistraße'},
#              'Ständlerstraße': {'Ständlerstraße'},
#              'Sudetendeutschestraße': {'Sudetendeutschestraße'},
#              'Suessenguthstraße': {'Suessenguthstraße'},
#              'Säulenstraße': {'Säulenstraße'},
#              'Taimerhofstraße': {'Taimerhofstraße'},
#              'Tal': {'Tal'},
#              'Taubensteinweg': {'Taubensteinweg'},
#              'Taubenstraße': {'Taubenstraße'},
#              'Taxisstraße': {'Taxisstraße'},
#              'Terofalstraße': {'Terofalstraße'},
#              'Thaddäus-Eck-Straße': {'Thaddäus-Eck-Straße'},
#              'Theatinerstraße': {'Theatinerstraße'},
#              'Thelottstraße': {'Thelottstraße'},
#              'Theo-Prosel-Weg': {'Theo-Prosel-Weg'},
#              'Theodor-Fischer-Straße': {'Theodor-Fischer-Straße'},
#              'Theodor-Kitt-Straße': {'Theodor-Kitt-Straße'},
#              'Theodor-Körner-Straße': {'Theodor-Körner-Straße'},
#              'Theodor-Lipps-Straße': {'Theodor-Lipps-Straße'},
#              'Therese-Giehse-Allee': {'Therese-Giehse-Allee'},
#              'Therese-Studer-Straße': {'Therese-Studer-Straße'},
#              'Theresienstraße': {'Theresienstraße'},
#              'Thierschplatz': {'Thierschplatz'},
#              'Thierseestraße': {'Thierseestraße'},
#              'Thuillestraße': {'Thuillestraße'},
#              'Tizianstraße': {'Tizianstraße'},
#              'Toni-Pfülf-Straße': {'Toni-Pfülf-Straße'},
#              'Torriweg': {'Torriweg'},
#              'Trappentreustraße': {'Trappentreustraße'},
#              'Traubestraße': {'Traubestraße'},
#              'Trautnerstraße': {'Trautnerstraße'},
#              'Trautweinstraße': {'Trautweinstraße'},
#              'Treffauerstraße': {'Treffauerstraße'},
#              'Triebstraße': {'Triebstraße'},
#              'Trollblumenstraße': {'Trollblumenstraße'},
#              'Trumppstraße': {'Trumppstraße'},
#              'Tulpenweg': {'Tulpenweg'},
#              'Tumblingerstraße': {'Tumblingerstraße'},
#              'Türkenstraße': {'Türkenstraße'},
#              'Ulmenstraße': {'Ulmenstraße'},
#              'Unertlstraße': {'Unertlstraße'},
#              'Universitätsstraße': {'Universitätsstraße'},
#              'Untermühlanger': {'Untermühlanger'},
#              'Uppenbornstraße': {'Uppenbornstraße'},
#              'Utzweg': {'Utzweg'},
#              'Valleystraße': {'Valleystraße'},
#              'Valpichlerstraße': {'Valpichlerstraße'},
#              'Veilchenstraße': {'Veilchenstraße'},
#              'Veith-Lutz-Straße': {'Veith-Lutz-Straße'},
#              'Verhoevenstraße': {'Verhoevenstraße'},
#              'Viktoriastraße': {'Viktoriastraße'},
#              'Vingerstraße': {'Vingerstraße'},
#              'Vinzenz-Schüpfer-Straße': {'Vinzenz-Schüpfer-Straße'},
#              'Vogelanger': {'Vogelanger'},
#              'Vogelloh': {'Vogelloh'},
#              'Volkartstraße': {'Volkartstraße'},
#              'Volksgartenstraße': {'Volksgartenstraße'},
#              'Vollmannstraße': {'Vollmannstraße'},
#              'Volmstraße': {'Volmstraße'},
#              'Von-Haller-Straße': {'Von-Haller-Straße'},
#              'Von-Kahr-Straße': {'Von-Kahr-Straße'},
#              'Von-Stauffenberg-Straße': {'Von-Stauffenberg-Straße'},
#              'Voßstraße': {'Voßstraße'},
#              'Wadlerstraße': {'Wadlerstraße'},
#              'Waisenhausstraße': {'Waisenhausstraße'},
#              'Waldeckstraße': {'Waldeckstraße'},
#              'Waldgartenstraße': {'Waldgartenstraße'},
#              'Waldhornstraße': {'Waldhornstraße'},
#              'Waldmeisterstraße': {'Waldmeisterstraße'},
#              'Wallmenichstraße': {'Wallmenichstraße'},
#              'Wastl-Witt-Straße': {'Wastl-Witt-Straße'},
#              'Waxensteinstraße': {'Waxensteinstraße'},
#              'Weg': {'Schönegger Weg', 'Kraillinger Weg'},
#              'Wehrlestraße': {'Wehrlestraße'},
#              'Weiglstraße': {'Weiglstraße'},
#              'Weiherweg': {'Weiherweg'},
#              'Weingartnerstraße': {'Weingartnerstraße'},
#              'Weitlstraße': {'Weitlstraße'},
#              'Weiß-Ferdl-Straße': {'Weiß-Ferdl-Straße'},
#              'Weißenfelderplatz': {'Weißenfelderplatz'},
#              'Welserstraße': {'Welserstraße'},
#              'Weltistraße': {'Weltistraße'},
#              'Wendl-Dietrich-Straße': {'Wendl-Dietrich-Straße'},
#              'Werinherstraße': {'Werinherstraße'},
#              'Werneckstraße': {'Werneckstraße'},
#              'Werner-Egk-Bogen': {'Werner-Egk-Bogen'},
#              'Werner-Friedmann-Bogen': {'Werner-Friedmann-Bogen'},
#              'Whistlerweg': {'Whistlerweg'},
#              'Widarkisstraße': {'Widarkisstraße'},
#              'Wiegandweg': {'Wiegandweg'},
#              'Wilbrechtstraße': {'Wilbrechtstraße'},
#              'Wilhelm-Busch-Straße': {'Wilhelm-Busch-Straße'},
#              'Wilhelm-Hertz-Straße': {'Wilhelm-Hertz-Straße'},
#              'Wilhelm-Kuhnert-Straße': {'Wilhelm-Kuhnert-Straße'},
#              'Wilhelm-Raabe-Straße': {'Wilhelm-Raabe-Straße'},
#              'Wilhelm-Weitling-Straße': {'Wilhelm-Weitling-Straße'},
#              'Wilhelmstraße': {'Wilhelmstraße'},
#              'Willibaldstraße': {'Willibaldstraße'},
#              'Wilramstraße': {'Wilramstraße'},
#              'Windeckstraße': {'Windeckstraße'},
#              'Winthirstraße': {'Winthirstraße'},
#              'Winzererstraße': {'Winzererstraße'},
#              'Wismat': {'Im Wismat'},
#              'Witzlebenstraße': {'Witzlebenstraße'},
#              'Wolfoltstraße': {'Wolfoltstraße'},
#              'Wolframstraße': {'Wolframstraße'},
#              'Wollnystraße': {'Wollnystraße'},
#              'Wotanstraße': {'Wotanstraße'},
#              'Wunderlichstraße': {'Wunderlichstraße'},
#              'Würmseeplatz': {'Würmseeplatz'},
#              'Würmseestraße': {'Würmseestraße'},
#              'Würmstraße': {'Würmstraße'},
#              'Würmtalstraße': {'Würmtalstraße'},
#              'Zaubzerstraße': {'Zaubzerstraße'},
#              'Zaunweg': {'Zaunweg'},
#              'Zedernweg': {'Zedernweg'},
#              'Zehentbauernstraße': {'Zehentbauernstraße'},
#              'Zeißstraße': {'Zeißstraße'},
#              'Zenettistraße': {'Zenettistraße'},
#              'Zennerstraße': {'Zennerstraße'},
#              'Zettlerstraße': {'Zettlerstraße'},
#              'Zieblandstraße': {'Zieblandstraße'},
#              'Zieglerstraße': {'Zieglerstraße'},
#              'Ziehrerstraße': {'Ziehrerstraße'},
#              'Zielstattstraße': {'Zielstattstraße'},
#              'Zinnienstraße': {'Zinnienstraße'},
#              'Zuccalistraße': {'Zuccalistraße'},
#              'Zugspitzstraße': {'Zugspitzstraße'},
#              'Zweibrückenstraße': {'Zweibrückenstraße'},
#              'Zwiedineckstraße': {'Zwiedineckstraße'},
#              'Zypressenweg': {'Zypressenweg'},
#              'Ährenfeld': {'Am Ährenfeld'}})

# %% [markdown]
# ## Audit amenity

# %%
### Audit the amenity tag of the xml file
audit_tag("amenity")
# Out:
# defaultdict(<class 'set'>,
#             {'atm': {'atm'},
#              'bank': {'bank'},
#              'bar': {'bar'},
#              'bench': {'bench'},
#              'bicycle_parking': {'bicycle_parking'},
#              'bicycle_rental': {'bicycle_rental'},
#              'cafe': {'cafe'},
#              'cinema': {'cinema'},
#              'clock': {'clock'},
#              'dentist': {'dentist'},
#              'doctors': {'doctors'},
#              'dormitory': {'dormitory'},
#              'fast_food': {'fast_food'},
#              'fire_station': {'fire_station'},
#              'food_court': {'food_court'},
#              'fountain': {'fountain'},
#              'ice_cream': {'ice_cream'},
#              'kindergarten': {'kindergarten'},
#              'marketplace': {'marketplace'},
#              'parking': {'parking'},
#              'parking_entrance': {'parking_entrance'},
#              'pharmacy': {'pharmacy'},
#              'place_of_worship': {'place_of_worship'},
#              'post_box': {'post_box'},
#              'pub': {'pub'},
#              'public_building': {'public_building'},
#              'recycling': {'recycling'},
#              'restaurant': {'restaurant'},
#              'school': {'school'},
#              'shelter': {'shelter'},
#              'social_facility': {'social_facility'},
#              'taxi': {'taxi'},
#              'telephone': {'telephone'},
#              'toilets': {'toilets'},
#              'vending_machine': {'vending_machine'},
#              'waste_basket': {'waste_basket'}})

# %% [markdown]
# ## Audit cuisine

# %%
### Audit the cuisine tag of the xml file any common cuisine type is expected to be valid
#audit_tag("cuisine")
audit_tag("cuisine", ["asian", "coffee_shop", "german", "greek", "indian",\
                     "italian", "pizza", "portuguese"], True)
# Out:
# defaultdict(<class 'set'>, {'regional': {'regional'}, 'coffee': {'coffee'}})

# %% [markdown]
# ## Audit phone

# %%
### Audit the phone tag of the xml file any number beginning with "+49 89 " is expected to be valid
#audit_tag("phone")
audit_tag_reg("phone", "^(?![+][0-9]{2}\s[0-9]{2}\s).*")
# Out:
# defaultdict(<class 'set'>,
#             {'+49 (0) 89 21 99 89 42': {'+49 (0) 89 21 99 89 42'},
#              '+49 (0) 89/932574': {'+49 (0) 89/932574'},
#              '+49 (0)89/895 580 68-0': {'+49 (0)89/895 580 68-0'},
#              '+49 800 344226622': {'+49 800 344226622'},
#              '+4989-36 10 33 97': {'+4989-36 10 33 97'},
#              '+498923709821': {'+498923709821'},
#              '089 20206561': {'089 20206561'},
#              '089 39 25 05': {'089 39 25 05'},
#              '089 507743': {'089 507743'},
#              '089 89059980': {'089 89059980'},
#              '089/2167-10090': {'089/2167-10090'},
#              '089/4482274': {'089/4482274'}})

# %% [markdown]
# # Prepare Data For Storage

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# ### Cleaning cuisine values

# %%
def clean_cuisine_value(item):
    """Porcess a string and replace invalid entries with vaild entries

    Args:
        item unprocesses value
        
    Returns:
        item cleansed value
    """
    
    ### dict that specifies the mapping of invalid to valid entries
    mapping = {
    "afghan": "afghanisch",
    "afghani": "afghanisch",
    "israel": "israeli",
    "doener": "döner",
    "mediteran": "mediterranean",
    "vietnam": "vietnamese",
    "türkisch": "turkish"
    }
    
    ### Processing of the string
    item = item.split(',')[0]
    item = item.split(';')[0]
    item = item.split('_')[0]
    item = item.lower()
    
    ### Loop through the mapping dict and replace the invalid values
    for key, value in mapping.items():
        
        if item == key:
            
            item = value
    
    return item

# %% [markdown]
# ### Cleaning amenity values

# %%
def clean_amenity_value(item):
    """Porcess a string and replace invalid entries with vaild entries

    Args:
        item unprocesses value
        
    Returns:
        item cleansed value
    """
        
    ### dict that specifies the mapping of invalid to valid entries
    mapping = {
    "automatenservice": "atm",
    "baggage checkroom": "baggage_checkroom",
    "no": None
    }
    
    ### Processing of the string
    item = item.lower()
    
    ### Loop through the mapping dict and replace the invalid values
    for key, value in mapping.items():
        
        if item == key:
            
            item = value
    
    return item

# %% [markdown]
# ### Clean phone

# %%
def clean_phone_value(value):
    """Porcess a phone number and replace invalid entries with vaild entries

    Args:
        value unprocesses value
        
    Returns:
        vaule cleansed value
    """
    
    ### Remove punctation of the phone number
    value = "".join(c for c in value if c not in ('(', ')', '-', '/'))
    
    ### Proces the phone number
    char_list = list(value)
    if len(char_list) >= 10:
        if char_list[0] == '0':
            del char_list[0]

        if char_list[3] == '8':
            char_list.insert(3, '0')

        if char_list[3] == '0':
            char_list[3] = ' '

        if char_list[4] == '0':
            del char_list[4]
            del char_list[4]

        if char_list[6] != ' ':
            char_list.insert(6, ' ')

        if char_list[0] == '+':
            value = ''.join(char_list)
        else:
            value = '+49 ' + ''.join(char_list)
    else:
        return None
            
    ### Check if phone number is valid    
    audit_tag_type_re = re.compile("^(?![+][0-9]{2}\s[0-9]{2}\s).*", re.IGNORECASE)
    
    m = audit_tag_type_re.search(value)
    
    ### Return just if phone number is valid
    if m:
        return value

# %% [markdown]
# ## Converting the data into json style and clean it

# %%
def convert_clean_xml_data():
    """Process the data in json style format and clean it

    Args:
        None
        
    Returns:
        entry_list cleansed data in a json style format
    """
        
    entry_list = []

    ### Load xml file
    osm_file = open(DATASET_PATH, "rb")
    
    ### Loops over the xml file and process it in cleaned json style format
    for event, element in ElementTree.iterparse(osm_file, events=("start",)):

        ### Just consider the tags node or way
        if element.tag == "node" or element.tag == "way":
            
            ### Container for the json data
            json_data = dict()
            
            ### Loops of the tags in the node tag
            for node in element.iter('node'):
                
                json_data['id'] = node.attrib['id']
                json_data['type'] = element.tag
                json_data['visibile'] = 'true'

                created_fields = dict()
                created_fields['version'] = node.attrib['version']
                created_fields['changeset'] = node.attrib['changeset']
                created_fields['timestamp'] = node.attrib['timestamp']
                created_fields['user'] = node.attrib['user']
                created_fields['uid'] = node.attrib['uid']
                json_data['created'] = created_fields

                postion_list = []
                postion_list.append(node.attrib['lat'])
                postion_list.append(node.attrib['lon'])
                json_data['pos'] = postion_list
             
            ### Loops of the tags in the way tag
            for node in element.iter('way'):

                json_data['id'] = node.attrib['id']
                json_data['type'] = element.tag
                json_data['visibile'] = 'true'

                created_fields = dict()
                created_fields['version'] = node.attrib['version']
                created_fields['changeset'] = node.attrib['changeset']
                created_fields['timestamp'] = node.attrib['timestamp']
                created_fields['user'] = node.attrib['user']
                created_fields['uid'] = node.attrib['uid']
                json_data['created'] = created_fields

            ### Container for the adress data
            address_fields = dict()
            
            ### Loops of the tags in the tag tag
            for tag in element:
                if tag.tag == 'tag':

                    if tag.attrib['k'] == "addr:housenumber":
                        address_fields['housenumber'] = tag.attrib['v']

                    if tag.attrib['k'] == "addr:postcode" :
                        address_fields['postcode'] = tag.attrib['v']

                    if tag.attrib['k'] == "addr:street" :
                        address_fields['street'] = tag.attrib['v']

                    if tag.attrib['k'] == "amenity" :
                        item = clean_amenity_value(tag.attrib['v'])
                        json_data['amenity'] = item

                    if tag.attrib['k'] == "cuisine" :
                        item = clean_cuisine_value(tag.attrib['v'])
                        json_data['cuisine'] = item

                    if tag.attrib['k'] == "name" :
                        json_data['name'] = tag.attrib['v']

                    if tag.attrib['k'] == "phone" :
                        item = clean_phone_value(tag.attrib['v'])
                        json_data['phone'] = item

            json_data['address'] = address_fields

            entry_list.append(json_data)

    ### Close the connection to the file
    osm_file.close()
    
    return entry_list

# %% [markdown]
# # Store The Data in MongoDB

# %%
### Convert the xml data into json and clean the found errors in the auditing process
json_entries = convert_clean_xml_data()

### Etablish a connection to a mongdb instance
client = MongoClient(MONGODB_DB)

### Open database openStreetMapData and store it
db = client.openStreetMapData

### Insert entries into database table map
for entry in json_entries:
    entry['_id']  = ObjectId()
    db.map.insert_one(entry)

# %% [markdown]
# # Query The Dataset in MongoDB

# %%
print("Query The Dataset in MongoDB")

### Size of the database
print("Size of database: " + str(round(db.command("dbstats")['storageSize'] / (1024*1024))) + " MB")

print('-----')

# Number of documents
print('Number of documents: ' + str(db.map.find().count()))

print('-----')

# Number of nodes
print('Number of nodes: ' + str(db.map.find({"type":"node"}).count()))

print('-----')

# Number of ways
print('Number of ways: ' + str(db.map.find({"type":"way"}).count()))

print('-----')

# Number of unique users
print('Number of unique users: ' + str(len(db.map.distinct("created.user"))))

print('-----')

# Top 10 contributing user
users = db.map.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":10}])
print("Top 10 most active users:")
for i in range(10):
    print(users.next())
    
print('-----')
    
# Number of cuisines appearing only once 
count_single_cousine = db.map.aggregate([{"$group":{"_id":"$cuisine", "count":{"$sum":1}}}, {"$group":{"_id":"$count", "count single cousines":{"$sum":1}}}, {"$sort":{"_id":1}}, {"$limit":1}])
print("Number of cuisines appearing only once: " + str(count_single_cousine.next()["count single cousines"]))

print('-----')

# Cuisines appearing only once
cousines = db.map.aggregate([{"$group":{"_id":"$cuisine", "count":{"$sum":1}}}, {"$sort":{"count":1}}, {"$limit":10}, {'$match':{'count': {'$lte': 1}}}])
print("Sample of 5 cousine appearing only once:")
for i in range(5):
    print(cousines.next()["_id"])

print('-----')

# Postcode areas with the highest bar density
postcode_bars = db.map.aggregate([{"$match":{"amenity":{"$exists":1}, "amenity":"bar"}},
{"$match":{"address.postcode":{"$exists":1}}},
{"$group":{"_id":"$address.postcode", "count":{"$sum":1}}},
{"$sort":{"count":-1}}, {"$limit":5}
])

print("Top 5 bar density postcode areas:")
for i in range(5):
    print(postcode_bars.next())
# Out:
# Query The Dataset in MongoDB
# Size of database: 112 MB
# -----
# Number of documents: 1695297
# -----
# Number of nodes: 1420595
# -----
# Number of ways: 274702
# -----
# Number of unique users: 2881
# -----
# Top 10 most active users:
# {'_id': 'BeKri', 'count': 179732}
# {'_id': 'rolandg', 'count': 131495}
# {'_id': 'ToniE', 'count': 131199}
# {'_id': 'heilbron', 'count': 117306}
# {'_id': 'KonB', 'count': 107448}
# {'_id': 'Basstoelpel', 'count': 60448}
# {'_id': 'marek kleciak', 'count': 54966}
# {'_id': 'osmkurt', 'count': 44081}
# {'_id': 'Filius Martii', 'count': 36452}
# {'_id': 'ludwich', 'count': 31992}
# -----
# Number of cuisines appearing only once: 58
# -----
# Sample of 5 cousine appearing only once:
# snack
# yugoslavian
# senegalese
# panasia
# pasta
# -----
# Top 5 bar density postcode areas:
# {'_id': '80469', 'count': 27}
# {'_id': '80331', 'count': 10}
# {'_id': '80802', 'count': 9}
# {'_id': '80799', 'count': 8}
# {'_id': '81667', 'count': 8}

# %% [markdown]
# # Conclusion

# %% [markdown]
# The review of the data of the Munich area shows that it is already very tidy. But there are some minor inconsitis like using different languages for tagging amenities and different notations for formatting phone numbers.
# A better data processor could adress this issues, by considering all notations for phone numbers used in Germany and format it all to the same format and identify the tags that are not in the english language and translate them.
